# %% [markdown]
# # Analyzing Cisplatin-Binding Transcripts via GLM-SAE Knowledge Graphs

# %%
import networkx as nx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from networkx.readwrite import json_graph

import os, json

with open("data/cisplatin_neg45k_kg.json") as f:
    data = json.load(f)

G: nx.MultiDiGraph = json_graph.node_link_graph(data, edges="edges")
print(G)
# Out:
# MultiDiGraph with 7141 nodes and 4197345 edges

# %%
# graph is large, so lets trim down a version we can visualize
OG = G.copy()

# filter features that only respond to one token
to_remove = [n for n in G.nodes if G.in_degree(n) == 1]
G.remove_nodes_from(to_remove)
print(G)

# the '<cls>' token is the 'start' token and does not encode genetic info
if G.has_node('<cls>'):
    G.remove_node('<cls>')
    print(G)

# find average edge bundle size
edge_sizes = {(u,v): len(G.get_edge_data(u, v)) for u, v, k in G.edges}
avg_edge_size = sum(edge_sizes.values()) / len(edge_sizes)
print(f"Average edge bundle size: {avg_edge_size}")
print(f"Median edge bundle size: {np.median(list(edge_sizes.values()))}")
print(f"Number of edge bundles: {len(edge_sizes)}")
print(f"Max edge bundle size: {max(edge_sizes.values())}")
print(f"Min edge bundle size: {min(edge_sizes.values())}")
print(f"Standard deviation of edge bundle sizes: {pd.Series(edge_sizes.values()).std()}")

# filter edges that have less than 5 samples in their bundle, then show new descriptive stats
print("---------- Filtering edges with less than 5 samples in their bundle ----------")
to_remove = [key for key, size in edge_sizes.items() if size < 5]
for ebundle in to_remove:
    u, v = ebundle
    keys = list(G.get_edge_data(u, v).keys())
    for k in keys:
        G.remove_edge(u, v, k)
# G.remove_edges_from(to_remove)
print(G)

edge_sizes = {(u,v): len(G.get_edge_data(u, v)) for u, v, k in G.edges}
avg_edge_size = sum(edge_sizes.values()) / len(edge_sizes)
print(f"Average edge bundle size: {avg_edge_size}")
print(f"Median edge bundle size: {np.median(list(edge_sizes.values()))}")
print(f"Number of edge bundles: {len(edge_sizes)}")
print(f"Max edge bundle size: {max(edge_sizes.values())}")
print(f"Min edge bundle size: {min(edge_sizes.values())}")
print(f"Standard deviation of edge bundle sizes: {pd.Series(edge_sizes.values()).std()}")

# re-filter features that only respond to one token or are disconnected from the graph
to_remove = [n for n in G.nodes if G.in_degree(n) <= 1 and type(n) == int]
G.remove_nodes_from(to_remove)
print(G)
# Out:
# MultiDiGraph with 6824 nodes and 4197028 edges
# MultiDiGraph with 6823 nodes and 4156725 edges
# Average edge bundle size: 6.9515217598531
# Median edge bundle size: 1.0
# Number of edge bundles: 597959
# Max edge bundle size: 6057
# Min edge bundle size: 1
# Standard deviation of edge bundle sizes: 46.394946770635855
# ---------- Filtering edges with less than 5 samples in their bundle ----------
# MultiDiGraph with 6823 nodes and 3387035 edges
# Average edge bundle size: 34.867562281243565
# Median edge bundle size: 9.0
# Number of edge bundles: 97140
# Max edge bundle size: 6057
# Min edge bundle size: 5
# Standard deviation of edge bundle sizes: 110.97611840464725
# MultiDiGraph with 5568 nodes and 3387035 edges

# %%
# use annotations to create two graphs of coding and non-coding genomic regions
coding_regions = [e for e in G.edges(data=True, keys=True) if len(e[3]["annotations"]) != 0]
non_coding_regions = [e for e in G.edges(data=True, keys=True) if len(e[3]["annotations"]) == 0]

G_coding = nx.MultiDiGraph()
for edge in coding_regions:
    G_coding.add_edge(edge[0], edge[1], edge[2], **edge[3])
G_non_coding = nx.MultiDiGraph()
for edge in non_coding_regions:
    G_non_coding.add_edge(edge[0], edge[1], edge[2], **edge[3])

print(f"Coding graph: {G_coding}")
print(f"Non-coding graph: {G_non_coding}")
# Out:
# Coding graph: MultiDiGraph with 5415 nodes and 812369 edges
# Non-coding graph: MultiDiGraph with 5567 nodes and 2574666 edges

# %%
def node_color(x):
    return "lightblue" if type(x) == str else "red"

# %%
print("--- CODING SEQUENCES ---")

pagerank = nx.pagerank(G_coding)
sorted_pr = sorted(pagerank.items(), key=lambda item: item[1], reverse=True)
print("Top 10 nodes by PageRank:")
for node, pr in sorted_pr[:10]:
    print(f"Node: {node}, PageRank: {pr}")

degree_centrality = nx.out_degree_centrality(G_coding)
sorted_degree = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)
print("Top 10 nodes by Out-Degree Centrality:")
for node, dc in sorted_degree[:10]:
    print(f"Node: {node}, Out-Degree Centrality: {dc}")

#nx.draw(G_coding, pos=nx.forceatlas2_layout(G_coding), with_labels=False, node_size=10, font_size=4, node_color=[node_color(n) for n in G_coding.nodes()])
# Out:
# --- CODING SEQUENCES ---
# Top 10 nodes by PageRank:
# Node: 8161, PageRank: 0.19687593503427994
# Node: 7030, PageRank: 0.0372370455963754
# Node: 7949, PageRank: 0.014281489531611225
# Node: 1422, PageRank: 0.007482991577658241
# Node: 5984, PageRank: 0.006915740386288211
# Node: 2453, PageRank: 0.0048780476203867185
# Node: 9452, PageRank: 0.004333574960662349
# Node: 9021, PageRank: 0.003083666406978392
# Node: 835, PageRank: 0.002501853543098789
# Node: 5741, PageRank: 0.0024684622382828867
# Top 10 nodes by Out-Degree Centrality:
# Node: TTTTTT, Out-Degree Centrality: 0.25434059844846696
# Node: AAAAAA, Out-Degree Centrality: 0.2133357960842261
# Node: ATTTTT, Out-Degree Centrality: 0.18729220539342445
# Node: TTTTTA, Out-Degree Centrality: 0.17713335796084226
# Node: G, Out-Degree Centrality: 0.16715921684521612
# Node: TATTTT, Out-Degree Centrality: 0.16642039157739194
# Node: AAAAAT, Out-Degree Centrality: 0.16512744735869966
# Node: TTTTTG, Out-Degree Centrality: 0.16217214628740304
# Node: TTTTAA, Out-Degree Centrality: 0.15293683043960105
# Node: TTATTT, Out-Degree Centrality: 0.15238271148873292

# %%
print("--- NON-CODING SEQUENCES ---")

pagerank = nx.pagerank(G_non_coding)
sorted_pr = sorted(pagerank.items(), key=lambda item: item[1], reverse=True)
print("Top 10 nodes by PageRank:")
for node, pr in sorted_pr[:10]:
    print(f"Node: {node}, PageRank: {pr}")

degree_centrality = nx.out_degree_centrality(G_non_coding)
sorted_degree = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)
print("Top 10 nodes by Out-Degree Centrality:")
for node, dc in sorted_degree[:10]:
    print(f"Node: {node}, Out-Degree Centrality: {dc}")


#nx.draw(G_non_coding, pos=nx.forceatlas2_layout(G_non_coding), with_labels=False, node_size=10, font_size=4, node_color=[node_color(n) for n in G_non_coding.nodes()])
# Out:
# --- NON-CODING SEQUENCES ---
# Top 10 nodes by PageRank:
# Node: 8161, PageRank: 0.16845245564335232
# Node: 7030, PageRank: 0.029691228481648322
# Node: 3378, PageRank: 0.012824458852998533
# Node: 4793, PageRank: 0.0095631601344086
# Node: 7949, PageRank: 0.006341539512496292
# Node: 1422, PageRank: 0.006265641335004452
# Node: 5984, PageRank: 0.00532525965976957
# Node: 1545, PageRank: 0.004422141159927955
# Node: 835, PageRank: 0.0043350835181561135
# Node: 7612, PageRank: 0.004331091308329926
# Top 10 nodes by Out-Degree Centrality:
# Node: G, Out-Degree Centrality: 1.7919511318720804
# Node: C, Out-Degree Centrality: 1.7642831476823573
# Node: A, Out-Degree Centrality: 1.6658282429033417
# Node: T, Out-Degree Centrality: 1.5449155587495509
# Node: AAAAAA, Out-Degree Centrality: 0.8841178584261589
# Node: TTTTTT, Out-Degree Centrality: 0.8514193316564859
# Node: AAAAAT, Out-Degree Centrality: 0.5979159180740209
# Node: ATTTTT, Out-Degree Centrality: 0.5725835429392742
# Node: TAAAAA, Out-Degree Centrality: 0.541501976284585
# Node: AAAATA, Out-Degree Centrality: 0.4996406755300036

# %%
# COMPARE TO ORIGINAL GRAPH
# use page rank to measure centrality
pagerank = nx.pagerank(OG)
sorted_pagerank = sorted(pagerank.items(), key=lambda x: x[1], reverse=True)

print("Nodes ranked by PageRank:")
for node, score in sorted_pagerank[:10]:  # top 10 nodes
    print(f"{node}: {score}")
# Out:
# Nodes ranked by PageRank:
# 8161: 0.10874592750416887
# 7030: 0.021950368456290115
# 3378: 0.007113011140264806
# 4793: 0.005248423700916205
# 7949: 0.004543801336913997
# 5984: 0.004379874340400829
# 1422: 0.00405684001443536
# 2453: 0.0032858460917511473
# 7612: 0.002891826775626524
# 835: 0.0028105569144162477

# %%
# COMPARE TO ORIGINAL GRAPH
# compare with degree centrality for important tokens
degree_centrality = nx.out_degree_centrality(OG)
sorted_degree = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)

print("Nodes ranked by Degree Centrality:")
for node, score in sorted_degree[:10]:  # top 10 nodes
    print(f"{node}: {score}")
# Out:
# Nodes ranked by Degree Centrality:
# <cls>: 5.644677871148459
# G: 1.6274509803921569
# C: 1.5823529411764705
# A: 1.4928571428571427
# T: 1.3866946778711484
# TTTTTT: 0.8684873949579831
# AAAAAA: 0.8638655462184873
# ATTTTT: 0.6273109243697479
# AAAAAT: 0.6194677871148458
# TAAAAA: 0.5546218487394957

# %%
# export to cytoscape for visualization
# Didn't work for the large graph, so just keeping for documentation
for node in OG.nodes():
    OG.nodes[node]['id'] = node

cyto_data = nx.readwrite.json_graph.cytoscape_data(OG)
with open("data/cisplatin_neg45k_kg_cyto.json", "w") as f:
    json.dump(cyto_data, f)

# %% [markdown]
# # Using Knowledge Graph Patterns to Create Gene Sets
#
# Note the strong centrality in multiple segments of the graph for features 3378, 407, and 4793, as well as typical base pairing hairpin motifs with high GC content in the outbound central nodes.
#
# By gathering data from the edges associated with each major feature, we can create gene sets based on GLM feature output.

# %%
# Note that our non-coding graph lacks annotations by definition, so we will only create gene sets for coding regions
# central feat 0
best_feature = sorted_pagerank[0][0]
best_feature2 = sorted_pagerank[1][0]
best_feature3 = sorted_pagerank[2][0]

edges = G_coding.in_edges(best_feature, data="annotations")

genes = []
motifs = []
for u, v, annotations in edges:
    for key, val in annotations.items():
        genes.append(val["gene_id"])
        motifs.append(u)

os.makedirs("data/neg_gene_sets", exist_ok=True)

with open(f"data/neg_gene_sets/feature_{best_feature}_genes.txt", "w") as f:
    f.write("\n".join(set(genes)))

with open(f"data/neg_gene_sets/feature_{best_feature}_motifs.txt", "w") as f:
    f.write("\n".join(set(motifs)))

# 407
edges = G_coding.in_edges(best_feature2, data="annotations")

genes = []
motifs = []
for u, v, annotations in edges:
    for key, val in annotations.items():
        genes.append(val["gene_id"])
        motifs.append(u)

with open(f"data/neg_gene_sets/feature_{best_feature2}_genes.txt", "w") as f:
    f.write("\n".join(set(genes)))

with open(f"data/neg_gene_sets/feature_{best_feature2}_motifs.txt", "w") as f:
    f.write("\n".join(set(motifs)))


# 4793
edges = G_coding.in_edges(best_feature3, data="annotations")

genes = []
motifs = []
for u, v, annotations in edges:
    for key, val in annotations.items():
        genes.append(val["gene_id"])
        motifs.append(u)

with open(f"data/neg_gene_sets/feature_{best_feature3}_genes.txt", "w") as f:
    f.write("\n".join(set(genes)))

with open(f"data/neg_gene_sets/feature_{best_feature3}_motifs.txt", "w") as f:
    f.write("\n".join(set(motifs)))


# overall gene sets for comparison
edges = G_coding.edges(data="annotations")
genes = []
motifs = []
for u, v, annotations in edges:
    for key, val in annotations.items():
        genes.append(val["gene_id"])
        motifs.append(u)
with open("data/neg_gene_sets/all_coding_genes.txt", "w") as f:
    f.write("\n".join(set(genes)))
with open("data/neg_gene_sets/all_coding_motifs.txt", "w") as f:
    f.write("\n".join(set(motifs)))

# %%
# free up memory
del G
del G_coding
del G_non_coding
del cyto_data
del edges
del genes
del motifs
del sorted_pagerank
del sorted_pr

# %% [markdown]
# # Community Detection

# %%
# Louvain
communities = nx.community.louvain_communities(OG.to_undirected(), resolution=1.5)
print(f"Found {len(communities)} communities")
# Out:
# Found 43 communities

# %%
subgraph_list = []
for i, c in enumerate(communities):
    graph = OG.subgraph(c)
    central_features = sorted(nx.in_degree_centrality(graph).items(), key=lambda x: x[1], reverse=True)[:5]
    central_motifs = sorted(nx.out_degree_centrality(graph).items(), key=lambda x: x[1], reverse=True)[:5]

    print(f"Community {i}:")
    print(" Central Features (In-Degree Centrality):")
    for node, cent in central_features:
        print(f"  Node: {node}, In-Degree Centrality: {cent}")
    print(" Central Motifs (Out-Degree Centrality):")
    for node, cent in central_motifs:
        print(f"  Node: {node}, Out-Degree Centrality: {cent}")
    graph = graph.to_undirected()

    # Export each community to a separate JSON file
    if not os.path.exists(f"data/negKG_louvain_communities/{i}"):
        os.makedirs(f"data/negKG_louvain_communities/{i}", exist_ok=True)
    with open(f"data/negKG_louvain_communities/{i}/graph.json", "w") as f:
        json.dump(json_graph.node_link_data(graph, edges="edges"), f)

    subgraph_list.append({"g":graph, "central_feat": central_features[0], "central_motif": central_motifs[0]})
    print("")
    # Visualize the community
#    nx.draw(graph, pos=nx.kamada_kawai_layout(graph), with_labels=False, node_size=10, font_size=4, node_color=[node_color(n) for n in graph.nodes()])
#    plt.title(f"Community {i}")
#    plt.show()
# Out:
# Community 0:
#  Central Features (In-Degree Centrality):
#   Node: 5746, In-Degree Centrality: 35124.0
#   Node: <cls>, In-Degree Centrality: 0.0
#  Central Motifs (Out-Degree Centrality):
#   Node: <cls>, Out-Degree Centrality: 35124.0
#   Node: 5746, Out-Degree Centrality: 0.0
#
# Community 1:
#  Central Features (In-Degree Centrality):
#   Node: 7030, In-Degree Centrality: 323.2313432835821
#   Node: 2471, In-Degree Centrality: 6.384328358208955
#   Node: 720, In-Degree Centrality: 5.527985074626866
#   Node: 1003, In-Degree Centrality: 4.227611940298507
#   Node: 954, In-Degree Centrality: 4.210820895522388
#  Central Motifs (Out-Degree Centrality):
#   Node: AGAAAA, Out-Degree Centrality: 5.975746268656716
#   Node: TTTTTA, Out-Degree Centrality: 5.656716417910448
#   Node: AAGAAA, Out-Degree Centrality: 5.5783582089552235
#   Node: TTTTAA, Out-Degree Centrality: 5.317164179104478
#   Node: ATTTTT, Out-Degree Centrality: 5.255597014925373
#
# Community 2:
#  Central Features (In-Degree Centrality):
#   Node: 1845, In-Degree Centrality: 9.22936507936508
#   Node: 7949, In-Degree Centrality: 8.313492063492063
#   Node: 1422, In-Degree Centrality: 6.447619047619048
#   Node: 407, In-Degree Centrality: 6.292063492063492
#   Node: 7612, In-Degree Centrality: 5.68968253968254
#  Central Motifs (Out-Degree Centrality):
#   Node: G, Out-Degree Centrality: 6.395238095238096
#   Node: C, Out-Degree Centrality: 6.241269841269841
#   Node: A, Out-Degree Centrality: 5.957936507936508
#   Node: T, Out-Degree Centrality: 5.7063492063492065
#   Node: CAGCAG, Out-Degree Centrality: 0.3047619047619048
#
# Community 3:
#  Central Features (In-Degree Centrality):
#   Node: 1389, In-Degree Centrality: 46.42028985507246
#   Node: 2216, In-Degree Centrality: 28.73913043478261
#   Node: 9040, In-Degree Centrality: 11.840579710144928
#   Node: 9681, In-Degree Centrality: 11.333333333333334
#   Node: 9748, In-Degree Centrality: 8.768115942028986
#  Central Motifs (Out-Degree Centrality):
#   Node: GGGATT, Out-Degree Centrality: 16.797101449275363
#   Node: ACAGGC, Out-Degree Centrality: 15.434782608695652
#   Node: ACAGAG, Out-Degree Centrality: 11.391304347826088
#   Node: GGAGTT, Out-Degree Centrality: 10.898550724637682
#   Node: TTTCAC, Out-Degree Centrality: 9.434782608695652
#
# Community 4:
#  Central Features (In-Degree Centrality):
#   Node: 4814, In-Degree Centrality: 174.72857142857143
#   Node: 9339, In-Degree Centrality: 68.62857142857143
#   Node: 1781, In-Degree Centrality: 66.22857142857143
#   Node: 1096, In-Degree Centrality: 12.385714285714286
#   Node: 2726, In-Degree Centrality: 9.842857142857143
#  Central Motifs (Out-Degree Centrality):
#   Node: AAAAAA, Out-Degree Centrality: 84.31428571428572
#   Node: AAAAAT, Out-Degree Centrality: 52.628571428571426
#   Node: AAAATA, Out-Degree Centrality: 39.528571428571425
#   Node: TAAAAA, Out-Degree Centrality: 32.31428571428572
#   Node: AAAATT, Out-Degree Centrality: 27.0
#
# Community 5:
#  Central Features (In-Degree Centrality):
#   Node: 4793, In-Degree Centrality: 24.879166666666666
#   Node: 5458, In-Degree Centrality: 13.237499999999999
#   Node: 1895, In-Degree Centrality: 3.8791666666666664
#   Node: 7940, In-Degree Centrality: 2.7041666666666666
#   Node: 6480, In-Degree Centrality: 2.158333333333333
#  Central Motifs (Out-Degree Centrality):
#   Node: TGTGTG, Out-Degree Centrality: 5.683333333333334
#   Node: GTGTGT, Out-Degree Centrality: 3.995833333333333
#   Node: TATATA, Out-Degree Centrality: 2.6083333333333334
#   Node: ATATAT, Out-Degree Centrality: 2.4791666666666665
#   Node: CACACA, Out-Degree Centrality: 1.625
#
# Community 6:
#  Central Features (In-Degree Centrality):
#   Node: 4831, In-Degree Centrality: 492.52941176470586
#   Node: 559, In-Degree Centrality: 17.294117647058822
#   Node: 2656, In-Degree Centrality: 14.76470588235294
#   Node: 1516, In-Degree Centrality: 10.51470588235294
#   Node: 1613, In-Degree Centrality: 8.882352941176471
#  Central Motifs (Out-Degree Centrality):
#   Node: TTTTTT, Out-Degree Centrality: 89.16176470588235
#   Node: TTTCTT, Out-Degree Centrality: 43.955882352941174
#   Node: CTTTTT, Out-Degree Centrality: 42.838235294117645
#   Node: TATTTT, Out-Degree Centrality: 41.19117647058823
#   Node: TTTTCT, Out-Degree Centrality: 38.294117647058826
#
# Community 7:
#  Central Features (In-Degree Centrality):
#   Node: 1636, In-Degree Centrality: 20.787096774193547
#   Node: 6347, In-Degree Centrality: 16.44516129032258
#   Node: 74, In-Degree Centrality: 12.503225806451614
#   Node: 7836, In-Degree Centrality: 9.761290322580646
#   Node: 2001, In-Degree Centrality: 8.825806451612904
#  Central Motifs (Out-Degree Centrality):
#   Node: TGGGAT, Out-Degree Centrality: 7.735483870967742
#   Node: TGGAGT, Out-Degree Centrality: 6.780645161290322
#   Node: TTGAGA, Out-Degree Centrality: 6.245161290322581
#   Node: TGAGAC, Out-Degree Centrality: 6.2
#   Node: CTCACT, Out-Degree Centrality: 5.664516129032258
#
# Community 8:
#  Central Features (In-Degree Centrality):
#   Node: 6445, In-Degree Centrality: 9.264797507788161
#   Node: 4554, In-Degree Centrality: 6.383177570093458
#   Node: 9656, In-Degree Centrality: 5.5607476635514015
#   Node: 2416, In-Degree Centrality: 4.339563862928348
#   Node: 7979, In-Degree Centrality: 4.242990654205608
#  Central Motifs (Out-Degree Centrality):
#   Node: GGGAGG, Out-Degree Centrality: 5.591900311526479
#   Node: GAGGCA, Out-Degree Centrality: 3.5856697819314642
#   Node: GGCAGG, Out-Degree Centrality: 3.398753894080997
#   Node: GCAGGA, Out-Degree Centrality: 2.588785046728972
#   Node: AGCACT, Out-Degree Centrality: 2.5171339563862927
#
# Community 9:
#  Central Features (In-Degree Centrality):
#   Node: 8453, In-Degree Centrality: 23.98507462686567
#   Node: 5840, In-Degree Centrality: 18.776119402985074
#   Node: 3381, In-Degree Centrality: 17.37313432835821
#   Node: 3566, In-Degree Centrality: 12.432835820895523
#   Node: 1037, In-Degree Centrality: 12.134328358208956
#  Central Motifs (Out-Degree Centrality):
#   Node: CTGGGA, Out-Degree Centrality: 23.119402985074625
#   Node: CTGAGG, Out-Degree Centrality: 17.880597014925375
#   Node: GGTTGC, Out-Degree Centrality: 7.985074626865671
#   Node: CTGAGA, Out-Degree Centrality: 6.17910447761194
#   Node: CTGAGT, Out-Degree Centrality: 5.343283582089552
#
# Community 10:
#  Central Features (In-Degree Centrality):
#   Node: 8358, In-Degree Centrality: 17.886666666666667
#   Node: 5781, In-Degree Centrality: 12.093333333333334
#   Node: 8720, In-Degree Centrality: 10.24
#   Node: 1108, In-Degree Centrality: 10.006666666666668
#   Node: 4524, In-Degree Centrality: 7.48
#  Central Motifs (Out-Degree Centrality):
#   Node: AGGCTG, Out-Degree Centrality: 14.746666666666668
#   Node: CCCAGG, Out-Degree Centrality: 9.573333333333334
#   Node: AGGCAG, Out-Degree Centrality: 8.126666666666667
#   Node: CCTGGG, Out-Degree Centrality: 7.773333333333333
#   Node: CAGCTA, Out-Degree Centrality: 7.16
#
# Community 11:
#  Central Features (In-Degree Centrality):
#   Node: 8853, In-Degree Centrality: 31.32051282051282
#   Node: 8847, In-Degree Centrality: 29.51282051282051
#   Node: 6885, In-Degree Centrality: 12.935897435897436
#   Node: 8337, In-Degree Centrality: 12.923076923076923
#   Node: 6506, In-Degree Centrality: 8.192307692307692
#  Central Motifs (Out-Degree Centrality):
#   Node: AATTAG, Out-Degree Centrality: 10.923076923076923
#   Node: CTGGGC, Out-Degree Centrality: 9.846153846153847
#   Node: GTGAAA, Out-Degree Centrality: 7.9743589743589745
#   Node: AACATG, Out-Degree Centrality: 7.794871794871795
#   Node: CTGGGT, Out-Degree Centrality: 7.256410256410256
#
# Community 12:
#  Central Features (In-Degree Centrality):
#   Node: 8356, In-Degree Centrality: 22.977777777777778
#   Node: 6485, In-Degree Centrality: 16.211111111111112
#   Node: 1271, In-Degree Centrality: 15.877777777777778
#   Node: 1497, In-Degree Centrality: 11.933333333333334
#   Node: 3255, In-Degree Centrality: 9.866666666666667
#  Central Motifs (Out-Degree Centrality):
#   Node: CACTGC, Out-Degree Centrality: 16.755555555555556
#   Node: GTGAGC, Out-Degree Centrality: 14.488888888888889
#   Node: GAGCCA, Out-Degree Centrality: 10.977777777777778
#   Node: ACTCCA, Out-Degree Centrality: 8.88888888888889
#   Node: CACCAT, Out-Degree Centrality: 8.855555555555556
#
# Community 13:
#  Central Features (In-Degree Centrality):
#   Node: 1261, In-Degree Centrality: 36.932432432432435
#   Node: 4171, In-Degree Centrality: 26.54054054054054
#   Node: 7674, In-Degree Centrality: 20.256756756756758
#   Node: 860, In-Degree Centrality: 17.756756756756758
#   Node: 1666, In-Degree Centrality: 11.081081081081082
#  Central Motifs (Out-Degree Centrality):
#   Node: CAGCCT, Out-Degree Centrality: 28.783783783783786
#   Node: CCAGCC, Out-Degree Centrality: 16.83783783783784
#   Node: GGATTA, Out-Degree Centrality: 16.256756756756758
#   Node: GCACTC, Out-Degree Centrality: 10.986486486486488
#   Node: TGCACT, Out-Degree Centrality: 10.95945945945946
#
# Community 14:
#  Central Features (In-Degree Centrality):
#   Node: 6912, In-Degree Centrality: 31.850467289719624
#   Node: 7911, In-Degree Centrality: 11.130841121495326
#   Node: 4588, In-Degree Centrality: 11.093457943925232
#   Node: 2496, In-Degree Centrality: 10.990654205607475
#   Node: 6795, In-Degree Centrality: 9.672897196261681
#  Central Motifs (Out-Degree Centrality):
#   Node: GCCTGT, Out-Degree Centrality: 10.299065420560748
#   Node: AATCCC, Out-Degree Centrality: 10.093457943925232
#   Node: TTGGGA, Out-Degree Centrality: 9.785046728971961
#   Node: GTGGCT, Out-Degree Centrality: 8.757009345794392
#   Node: GTGGTG, Out-Degree Centrality: 8.42056074766355
#
# Community 15:
#  Central Features (In-Degree Centrality):
#   Node: 8161, In-Degree Centrality: 484.08926875593545
#   Node: 5961, In-Degree Centrality: 1.0911680911680912
#   Node: 1838, In-Degree Centrality: 0.5887939221272555
#   Node: 2971, In-Degree Centrality: 0.5242165242165242
#   Node: 1658, In-Degree Centrality: 0.21462488129154797
#  Central Motifs (Out-Degree Centrality):
#   Node: ACATTT, Out-Degree Centrality: 1.3475783475783476
#   Node: TTCCTT, Out-Degree Centrality: 1.1671415004748338
#   Node: TTCTCT, Out-Degree Centrality: 1.1528964862298197
#   Node: TTCATT, Out-Degree Centrality: 1.1329534662867997
#   Node: TTAATT, Out-Degree Centrality: 1.123456790123457
#
# Community 16:
#  Central Features (In-Degree Centrality):
#   Node: 700, In-Degree Centrality: 22.678899082568808
#   Node: 3456, In-Degree Centrality: 18.57798165137615
#   Node: 1545, In-Degree Centrality: 14.357798165137616
#   Node: 6122, In-Degree Centrality: 7.660550458715597
#   Node: 7597, In-Degree Centrality: 7.220183486238533
#  Central Motifs (Out-Degree Centrality):
#   Node: GCCTCA, Out-Degree Centrality: 7.7431192660550465
#   Node: CCTGAC, Out-Degree Centrality: 5.541284403669725
#   Node: ACCTCA, Out-Degree Centrality: 5.467889908256881
#   Node: TGATCT, Out-Degree Centrality: 4.825688073394495
#   Node: CTCAAG, Out-Degree Centrality: 4.110091743119266
#
# Community 17:
#  Central Features (In-Degree Centrality):
#   Node: 1052, In-Degree Centrality: 24.807339449541285
#   Node: 1418, In-Degree Centrality: 21.394495412844037
#   Node: 4742, In-Degree Centrality: 21.28440366972477
#   Node: 6719, In-Degree Centrality: 20.63302752293578
#   Node: 8024, In-Degree Centrality: 10.541284403669726
#  Central Motifs (Out-Degree Centrality):
#   Node: GCTGGG, Out-Degree Centrality: 14.577981651376147
#   Node: ATTACA, Out-Degree Centrality: 11.568807339449542
#   Node: GATTAC, Out-Degree Centrality: 10.77981651376147
#   Node: TCCCAA, Out-Degree Centrality: 10.119266055045872
#   Node: AGCTGG, Out-Degree Centrality: 9.844036697247708
#
# Community 18:
#  Central Features (In-Degree Centrality):
#   Node: 329, In-Degree Centrality: 29.050847457627118
#   Node: 6992, In-Degree Centrality: 17.016949152542374
#   Node: 4281, In-Degree Centrality: 14.5
#   Node: 2494, In-Degree Centrality: 12.567796610169491
#   Node: 8857, In-Degree Centrality: 8.305084745762711
#  Central Motifs (Out-Degree Centrality):
#   Node: TGCCTC, Out-Degree Centrality: 9.203389830508474
#   Node: GTCTCA, Out-Degree Centrality: 7.11864406779661
#   Node: TGGCCA, Out-Degree Centrality: 6.728813559322034
#   Node: TCTCTA, Out-Degree Centrality: 6.364406779661017
#   Node: TGTCTC, Out-Degree Centrality: 6.1440677966101696
#
# Community 19:
#  Central Features (In-Degree Centrality):
#   Node: 7622, In-Degree Centrality: 36.825
#   Node: 10226, In-Degree Centrality: 12.8125
#   Node: 8939, In-Degree Centrality: 12.4375
#   Node: 7126, In-Degree Centrality: 11.775
#   Node: 8258, In-Degree Centrality: 11.700000000000001
#  Central Motifs (Out-Degree Centrality):
#   Node: GCAGTG, Out-Degree Centrality: 16.275000000000002
#   Node: GCCACC, Out-Degree Centrality: 13.0
#   Node: GATCAC, Out-Degree Centrality: 10.137500000000001
#   Node: GCCACT, Out-Degree Centrality: 9.950000000000001
#   Node: ACCAGC, Out-Degree Centrality: 8.8625
#
# Community 20:
#  Central Features (In-Degree Centrality):
#   Node: 7990, In-Degree Centrality: 15.67487684729064
#   Node: 5234, In-Degree Centrality: 13.94088669950739
#   Node: 9010, In-Degree Centrality: 8.108374384236454
#   Node: 2957, In-Degree Centrality: 7.039408866995074
#   Node: 1179, In-Degree Centrality: 4.54679802955665
#  Central Motifs (Out-Degree Centrality):
#   Node: CCCAGC, Out-Degree Centrality: 9.128078817733991
#   Node: AGCCAC, Out-Degree Centrality: 4.990147783251231
#   Node: GGCATG, Out-Degree Centrality: 4.620689655172414
#   Node: TCCAGC, Out-Degree Centrality: 4.41871921182266
#   Node: CCTGGC, Out-Degree Centrality: 4.41871921182266
#
# Community 21:
#  Central Features (In-Degree Centrality):
#   Node: 7664, In-Degree Centrality: 13.070707070707071
#   Node: 527, In-Degree Centrality: 11.989898989898991
#   Node: 7565, In-Degree Centrality: 11.626262626262628
#   Node: 6069, In-Degree Centrality: 9.545454545454547
#   Node: 6006, In-Degree Centrality: 7.3232323232323235
#  Central Motifs (Out-Degree Centrality):
#   Node: CACCTG, Out-Degree Centrality: 8.91919191919192
#   Node: TAATCC, Out-Degree Centrality: 7.93939393939394
#   Node: TGCCTG, Out-Degree Centrality: 7.838383838383839
#   Node: GCTAAT, Out-Degree Centrality: 7.737373737373738
#   Node: TGCCCA, Out-Degree Centrality: 7.242424242424243
#
# Community 22:
#  Central Features (In-Degree Centrality):
#   Node: 10234, In-Degree Centrality: 25.7741935483871
#   Node: 4034, In-Degree Centrality: 12.591397849462366
#   Node: 6696, In-Degree Centrality: 10.78494623655914
#   Node: 309, In-Degree Centrality: 9.78494623655914
#   Node: 8088, In-Degree Centrality: 9.731182795698926
#  Central Motifs (Out-Degree Centrality):
#   Node: GGTCTC, Out-Degree Centrality: 8.10752688172043
#   Node: GACCTC, Out-Degree Centrality: 6.67741935483871
#   Node: GATCTC, Out-Degree Centrality: 6.107526881720431
#   Node: GATTCT, Out-Degree Centrality: 5.849462365591398
#   Node: AACCCC, Out-Degree Centrality: 5.774193548387097
#
# Community 23:
#  Central Features (In-Degree Centrality):
#   Node: 7714, In-Degree Centrality: 28.941176470588236
#   Node: 9100, In-Degree Centrality: 26.223529411764705
#   Node: 8958, In-Degree Centrality: 15.0
#   Node: 1168, In-Degree Centrality: 12.847058823529412
#   Node: 4725, In-Degree Centrality: 9.670588235294117
#  Central Motifs (Out-Degree Centrality):
#   Node: CCAGGC, Out-Degree Centrality: 16.32941176470588
#   Node: CAGGCT, Out-Degree Centrality: 15.847058823529412
#   Node: TGGTCT, Out-Degree Centrality: 10.376470588235295
#   Node: TCACTG, Out-Degree Centrality: 9.51764705882353
#   Node: TGTTGC, Out-Degree Centrality: 6.235294117647059
#
# Community 24:
#  Central Features (In-Degree Centrality):
#   Node: 526, In-Degree Centrality: 33.44
#   Node: 8660, In-Degree Centrality: 31.94
#   Node: 8300, In-Degree Centrality: 18.82
#   Node: 1582, In-Degree Centrality: 17.080000000000002
#   Node: 7069, In-Degree Centrality: 15.56
#  Central Motifs (Out-Degree Centrality):
#   Node: GCCTCC, Out-Degree Centrality: 35.64
#   Node: ACTGCA, Out-Degree Centrality: 24.04
#   Node: CCTCAG, Out-Degree Centrality: 21.02
#   Node: GTGATC, Out-Degree Centrality: 16.98
#   Node: ACCTCC, Out-Degree Centrality: 11.5
#
# Community 25:
#  Central Features (In-Degree Centrality):
#   Node: 5871, In-Degree Centrality: 37.175000000000004
#   Node: 6784, In-Degree Centrality: 9.975000000000001
#   Node: 2857, In-Degree Centrality: 7.18125
#   Node: 1876, In-Degree Centrality: 5.331250000000001
#   Node: 4204, In-Degree Centrality: 5.2562500000000005
#  Central Motifs (Out-Degree Centrality):
#   Node: TACAGG, Out-Degree Centrality: 8.918750000000001
#   Node: GGTGGC, Out-Degree Centrality: 6.65
#   Node: CAGTGG, Out-Degree Centrality: 5.96875
#   Node: AGTAGC, Out-Degree Centrality: 5.3375
#   Node: AGTGGC, Out-Degree Centrality: 4.99375
#
# Community 26:
#  Central Features (In-Degree Centrality):
#   Node: 9291, In-Degree Centrality: 68.04761904761904
#   Node: 6753, In-Degree Centrality: 40.80952380952381
#   Node: 1114, In-Degree Centrality: 16.333333333333332
#   Node: 9021, In-Degree Centrality: 13.523809523809524
#   Node: 3993, In-Degree Centrality: 10.142857142857142
#  Central Motifs (Out-Degree Centrality):
#   Node: TTACAG, Out-Degree Centrality: 56.238095238095234
#   Node: CTGTAA, Out-Degree Centrality: 54.42857142857142
#   Node: CTACAG, Out-Degree Centrality: 13.476190476190476
#   Node: TTATAG, Out-Degree Centrality: 9.095238095238095
#   Node: CTATAA, Out-Degree Centrality: 6.619047619047619
#
# Community 27:
#  Central Features (In-Degree Centrality):
#   Node: 8911, In-Degree Centrality: 52.80645161290323
#   Node: 3071, In-Degree Centrality: 24.7741935483871
#   Node: 4914, In-Degree Centrality: 16.827956989247312
#   Node: 3407, In-Degree Centrality: 15.688172043010754
#   Node: 5312, In-Degree Centrality: 15.06451612903226
#  Central Motifs (Out-Degree Centrality):
#   Node: CAGGAG, Out-Degree Centrality: 16.505376344086024
#   Node: CCTGTA, Out-Degree Centrality: 15.473118279569894
#   Node: TGGGAG, Out-Degree Centrality: 14.860215053763442
#   Node: ATCCCA, Out-Degree Centrality: 12.655913978494624
#   Node: GCTGAG, Out-Degree Centrality: 12.344086021505378
#
# Community 28:
#  Central Features (In-Degree Centrality):
#   Node: 4955, In-Degree Centrality: 76.69565217391305
#   Node: 2069, In-Degree Centrality: 39.08695652173913
#   Node: 1150, In-Degree Centrality: 38.34782608695652
#   Node: 6801, In-Degree Centrality: 1.391304347826087
#   Node: 2542, In-Degree Centrality: 0.3913043478260869
#  Central Motifs (Out-Degree Centrality):
#   Node: AGTGCT, Out-Degree Centrality: 35.26086956521739
#   Node: CCCAAA, Out-Degree Centrality: 34.608695652173914
#   Node: GTGCTG, Out-Degree Centrality: 32.95652173913044
#   Node: ATGTTG, Out-Degree Centrality: 29.608695652173914
#   Node: GTGTTG, Out-Degree Centrality: 6.869565217391304
#
# Community 29:
#  Central Features (In-Degree Centrality):
#   Node: 7222, In-Degree Centrality: 71.5
#   Node: 5994, In-Degree Centrality: 70.25
#   Node: 4669, In-Degree Centrality: 7.416666666666666
#   Node: 7793, In-Degree Centrality: 3.333333333333333
#   Node: 7819, In-Degree Centrality: 0.3333333333333333
#  Central Motifs (Out-Degree Centrality):
#   Node: GAGTGC, Out-Degree Centrality: 69.08333333333333
#   Node: AAGTGC, Out-Degree Centrality: 66.25
#   Node: GAGTAC, Out-Degree Centrality: 6.916666666666666
#   Node: GAATGC, Out-Degree Centrality: 4.083333333333333
#   Node: GAGTGT, Out-Degree Centrality: 3.9166666666666665
#
# Community 30:
#  Central Features (In-Degree Centrality):
#   Node: 5002, In-Degree Centrality: 49.25
#   Node: 653, In-Degree Centrality: 14.392857142857142
#   Node: 2453, In-Degree Centrality: 11.392857142857142
#   Node: 4570, In-Degree Centrality: 2.25
#   Node: 5769, In-Degree Centrality: 0.3571428571428571
#  Central Motifs (Out-Degree Centrality):
#   Node: GGTTCA, Out-Degree Centrality: 23.57142857142857
#   Node: CGATTC, Out-Degree Centrality: 8.75
#   Node: CAATTC, Out-Degree Centrality: 8.071428571428571
#   Node: TGATTC, Out-Degree Centrality: 6.571428571428571
#   Node: GCTCAA, Out-Degree Centrality: 6.035714285714286
#
# Community 31:
#  Central Features (In-Degree Centrality):
#   Node: 6254, In-Degree Centrality: 44.815789473684205
#   Node: 4461, In-Degree Centrality: 15.723684210526315
#   Node: 5315, In-Degree Centrality: 13.421052631578947
#   Node: 8886, In-Degree Centrality: 11.31578947368421
#   Node: 5437, In-Degree Centrality: 7.328947368421052
#  Central Motifs (Out-Degree Centrality):
#   Node: CCTGCC, Out-Degree Centrality: 11.105263157894736
#   Node: CTGCCT, Out-Degree Centrality: 8.894736842105262
#   Node: ATTCTC, Out-Degree Centrality: 8.43421052631579
#   Node: GCAACC, Out-Degree Centrality: 7.644736842105263
#   Node: TCAAGC, Out-Degree Centrality: 7.421052631578947
#
# Community 32:
#  Central Features (In-Degree Centrality):
#   Node: 7320, In-Degree Centrality: 29.655913978494628
#   Node: 5022, In-Degree Centrality: 29.48387096774194
#   Node: 10066, In-Degree Centrality: 13.376344086021506
#   Node: 4660, In-Degree Centrality: 11.365591397849464
#   Node: 7618, In-Degree Centrality: 11.053763440860216
#  Central Motifs (Out-Degree Centrality):
#   Node: CCAGCT, Out-Degree Centrality: 11.580645161290324
#   Node: GTAATC, Out-Degree Centrality: 11.17204301075269
#   Node: GAGGCT, Out-Degree Centrality: 10.645161290322582
#   Node: CTAATT, Out-Degree Centrality: 8.870967741935484
#   Node: TGGCTC, Out-Degree Centrality: 7.580645161290323
#
# Community 33:
#  Central Features (In-Degree Centrality):
#   Node: 8097, In-Degree Centrality: 56.629629629629626
#   Node: 1579, In-Degree Centrality: 32.407407407407405
#   Node: 2044, In-Degree Centrality: 31.11111111111111
#   Node: 9138, In-Degree Centrality: 14.0
#   Node: 3995, In-Degree Centrality: 0.4444444444444444
#  Central Motifs (Out-Degree Centrality):
#   Node: CACTTT, Out-Degree Centrality: 29.962962962962962
#   Node: CACTCC, Out-Degree Centrality: 28.296296296296294
#   Node: GAGTCT, Out-Degree Centrality: 16.962962962962962
#   Node: CTCTCT, Out-Degree Centrality: 14.814814814814813
#   Node: CACTCT, Out-Degree Centrality: 14.592592592592592
#
# Community 34:
#  Central Features (In-Degree Centrality):
#   Node: 3384, In-Degree Centrality: 35.111111111111114
#   Node: 9263, In-Degree Centrality: 17.3
#   Node: 8940, In-Degree Centrality: 14.700000000000001
#   Node: 1490, In-Degree Centrality: 12.6
#   Node: 2591, In-Degree Centrality: 12.033333333333333
#  Central Motifs (Out-Degree Centrality):
#   Node: GGCTCA, Out-Degree Centrality: 14.711111111111112
#   Node: TGAGCC, Out-Degree Centrality: 14.511111111111111
#   Node: TGAACC, Out-Degree Centrality: 7.677777777777778
#   Node: GTGCAG, Out-Degree Centrality: 7.177777777777778
#   Node: CTGCAA, Out-Degree Centrality: 6.955555555555556
#
# Community 35:
#  Central Features (In-Degree Centrality):
#   Node: 4494, In-Degree Centrality: 18.156626506024097
#   Node: 4195, In-Degree Centrality: 14.180722891566266
#   Node: 288, In-Degree Centrality: 8.765060240963855
#   Node: 7571, In-Degree Centrality: 7.572289156626506
#   Node: 2346, In-Degree Centrality: 7.46987951807229
#  Central Motifs (Out-Degree Centrality):
#   Node: AGCCTG, Out-Degree Centrality: 8.078313253012048
#   Node: CCACTG, Out-Degree Centrality: 5.813253012048193
#   Node: AGTGAG, Out-Degree Centrality: 5.644578313253012
#   Node: CCACCA, Out-Degree Centrality: 5.5120481927710845
#   Node: AGACCA, Out-Degree Centrality: 4.843373493975903
#
# Community 36:
#  Central Features (In-Degree Centrality):
#   Node: 8204, In-Degree Centrality: 79.2
#   Node: 4023, In-Degree Centrality: 25.88
#   Node: 1441, In-Degree Centrality: 23.44
#   Node: 6391, In-Degree Centrality: 16.240000000000002
#   Node: 2333, In-Degree Centrality: 7.92
#  Central Motifs (Out-Degree Centrality):
#   Node: TTGTAT, Out-Degree Centrality: 30.28
#   Node: TTTGTA, Out-Degree Centrality: 27.0
#   Node: TGTATT, Out-Degree Centrality: 26.64
#   Node: GTATTT, Out-Degree Centrality: 25.560000000000002
#   Node: TTAGTA, Out-Degree Centrality: 25.52
#
# Community 37:
#  Central Features (In-Degree Centrality):
#   Node: 3568, In-Degree Centrality: 30.4
#   Node: 8992, In-Degree Centrality: 27.9
#   Node: 5984, In-Degree Centrality: 19.53333333333333
#   Node: 8102, In-Degree Centrality: 6.833333333333333
#   Node: 472, In-Degree Centrality: 0.4666666666666667
#  Central Motifs (Out-Degree Centrality):
#   Node: AGTGCA, Out-Degree Centrality: 27.8
#   Node: AGTTCA, Out-Degree Centrality: 11.333333333333334
#   Node: AGTTTG, Out-Degree Centrality: 10.0
#   Node: AGTTCG, Out-Degree Centrality: 9.066666666666666
#   Node: AATTCA, Out-Degree Centrality: 5.6
#
# Community 38:
#  Central Features (In-Degree Centrality):
#   Node: 4014, In-Degree Centrality: 20.915662650602407
#   Node: 319, In-Degree Centrality: 5.771084337349397
#   Node: 370, In-Degree Centrality: 4.393574297188755
#   Node: 2778, In-Degree Centrality: 3.827309236947791
#   Node: 5149, In-Degree Centrality: 3.3775100401606424
#  Central Motifs (Out-Degree Centrality):
#   Node: GCCTGG, Out-Degree Centrality: 6.3212851405622486
#   Node: GGCTGG, Out-Degree Centrality: 5.899598393574297
#   Node: CTCAGC, Out-Degree Centrality: 4.923694779116466
#   Node: CTTTGG, Out-Degree Centrality: 3.919678714859437
#   Node: GCCCAG, Out-Degree Centrality: 3.811244979919678
#
# Community 39:
#  Central Features (In-Degree Centrality):
#   Node: 2356, In-Degree Centrality: 19.764044943820224
#   Node: 1511, In-Degree Centrality: 13.202247191011235
#   Node: 10060, In-Degree Centrality: 13.0
#   Node: 5947, In-Degree Centrality: 11.719101123595506
#   Node: 4953, In-Degree Centrality: 11.573033707865168
#  Central Motifs (Out-Degree Centrality):
#   Node: TTGAAC, Out-Degree Centrality: 9.640449438202246
#   Node: CTTGAA, Out-Degree Centrality: 8.98876404494382
#   Node: GCTGGT, Out-Degree Centrality: 7.741573033707865
#   Node: CTCAAA, Out-Degree Centrality: 7.6966292134831455
#   Node: GCTTGA, Out-Degree Centrality: 7.280898876404494
#
# Community 40:
#  Central Features (In-Degree Centrality):
#   Node: 3378, In-Degree Centrality: 65.46790890269152
#   Node: 5741, In-Degree Centrality: 8.157349896480332
#   Node: 314, In-Degree Centrality: 6.2815734989648035
#   Node: 6781, In-Degree Centrality: 5.701863354037267
#   Node: 4692, In-Degree Centrality: 4.15527950310559
#  Central Motifs (Out-Degree Centrality):
#   Node: CTCCTG, Out-Degree Centrality: 4.432712215320911
#   Node: CCTCCC, Out-Degree Centrality: 3.695652173913044
#   Node: TCCCAG, Out-Degree Centrality: 3.6935817805383024
#   Node: CTCCCA, Out-Degree Centrality: 3.298136645962733
#   Node: GCTCAC, Out-Degree Centrality: 2.428571428571429
#
# Community 41:
#  Central Features (In-Degree Centrality):
#   Node: 3314, In-Degree Centrality: 26.506024096385545
#   Node: 1031, In-Degree Centrality: 12.987951807228916
#   Node: 8967, In-Degree Centrality: 12.55421686746988
#   Node: 6677, In-Degree Centrality: 10.240963855421688
#   Node: 3353, In-Degree Centrality: 9.650602409638555
#  Central Motifs (Out-Degree Centrality):
#   Node: GGAGGC, Out-Degree Centrality: 18.83132530120482
#   Node: TGTAAT, Out-Degree Centrality: 14.626506024096386
#   Node: TGCAGT, Out-Degree Centrality: 14.518072289156628
#   Node: TGAGGC, Out-Degree Centrality: 10.698795180722891
#   Node: AAAGTG, Out-Degree Centrality: 9.819277108433736
#
# Community 42:
#  Central Features (In-Degree Centrality):
#   Node: 3794, In-Degree Centrality: 22.03076923076923
#   Node: 3582, In-Degree Centrality: 21.953846153846154
#   Node: 3476, In-Degree Centrality: 13.584615384615386
#   Node: 171, In-Degree Centrality: 13.476923076923077
#   Node: 3835, In-Degree Centrality: 12.230769230769232
#  Central Motifs (Out-Degree Centrality):
#   Node: AGCCTC, Out-Degree Centrality: 15.446153846153846
#   Node: CTGGAG, Out-Degree Centrality: 14.307692307692308
#   Node: GCTGGA, Out-Degree Centrality: 13.53846153846154
#   Node: TGCTGG, Out-Degree Centrality: 12.723076923076924
#   Node: CCAAAG, Out-Degree Centrality: 12.430769230769231

# %%
# generate gene sets for central features and motifs in each community
for i, sub in enumerate(subgraph_list):
    graph = sub["g"]
    central_feat = sub["central_feat"][0]
    central_motif = sub["central_motif"][0]

    # central feature
    if type(central_feat) == int:
        edges = graph.edges(central_feat, data="annotations")
        genes = []
        motifs = []
        for u, v, annotations in edges:
            for key, val in annotations.items():
                motif = u if u != central_feat else v
                genes.append(val["gene_id"])
                motifs.append(motif)
        with open(f"data/negKG_louvain_communities/{i}/feature_{central_feat}_genes.txt", "w") as f:
            f.writelines('\n'.join(set(genes)))
        with open(f"data/negKG_louvain_communities/{i}/feature_{central_feat}_motifs.txt", "w") as f:
            f.writelines('\n'.join(set(motifs)))

    # central motif
    if type(central_motif) == str:
        edges = graph.edges(central_motif, data="annotations")
        genes = []
        features = []
        for u, v, annotations in edges:
            for key, val in annotations.items():
                feature = u if u != central_motif else v
                genes.append(val["gene_id"])
                features.append(str(feature))
        with open(f"data/negKG_louvain_communities/{i}/motif_{central_motif}_genes.txt", "w") as f:
            f.writelines('\n'.join(set(genes)))
        with open(f"data/negKG_louvain_communities/{i}/motif_{central_motif}_features.txt", "w") as f:
            f.writelines('\n'.join(set(features)))

# %% [markdown]
# # Gene Set Enrichment Analysis

# %%
# run R enrichment analysis on these gene sets using our custom script

neg_gene_sets = [f for f in os.listdir("data/neg_gene_sets") if f.endswith("_genes.txt")]
for gs in neg_gene_sets:
    os.system(f"Rscript enrich.R --gene_list data/neg_gene_sets/{gs} --outdir data/neg_gene_sets/enrich_{gs.split('_')[1]}")

for c in os.listdir("data/negKG_louvain_communities"):
    neg_gene_sets = [f for f in os.listdir(f"data/negKG_louvain_communities/{c}") if f.endswith("_genes.txt")]
    for gs in neg_gene_sets:
        os.system(f"Rscript enrich.R --gene_list data/negKG_louvain_communities/{c}/{gs} --outdir data/negKG_louvain_communities/{c}/enrich_{gs.split('_')[1]}")
# Out:
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# S Xu, E Hu, Y Cai, Z Xie, X Luo, L Zhan, W Tang, Q Wang, B Liu, R Wang,
# W Xie, T Wu, L Xie, G Yu. Using clusterProfiler to characterize
# multiomics data. Nature Protocols. 2024, 19(11):3292-3320
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/neg_gene_sets/feature_8161_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: BP"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/neg_gene_sets/enrich_8161"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# S Xu, E Hu, Y Cai, Z Xie, X Luo, L Zhan, W Tang, Q Wang, B Liu, R Wang,
# W Xie, T Wu, L Xie, G Yu. Using clusterProfiler to characterize
# multiomics data. Nature Protocols. 2024, 19(11):3292-3320
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# S Xu, E Hu, Y Cai, Z Xie, X Luo, L Zhan, W Tang, Q Wang, B Liu, R Wang,
# W Xie, T Wu, L Xie, G Yu. Using clusterProfiler to characterize
# multiomics data. Nature Protocols. 2024, 19(11):3292-3320
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/neg_gene_sets/feature_3378_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: BP"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/neg_gene_sets/enrich_3378"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan,
# X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal
# enrichment tool for interpreting omics data. The Innovation. 2021,
# 2(3):100141
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/neg_gene_sets/feature_7030_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: BP"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/neg_gene_sets/enrich_7030"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, and Qing-Yu He. ChIPseeker: an
# R/Bioconductor package for ChIP peak annotation, comparison and
# visualization. Bioinformatics. 2015, 31(14):2382-2383
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/neg_gene_sets/all_coding_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: BP"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/neg_gene_sets/enrich_coding"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Qing-Yu He. ReactomePA: an R/Bioconductor package for
# reactome pathway analysis and visualization. Molecular BioSystems.
# 2016, 12(2):477-479
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/1/motif_AGAAAA_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: BP"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/1/enrich_AGAAAA"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/1/feature_7030_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: BP"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/1/enrich_7030"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# S Xu, E Hu, Y Cai, Z Xie, X Luo, L Zhan, W Tang, Q Wang, B Liu, R Wang,
# W Xie, T Wu, L Xie, G Yu. Using clusterProfiler to characterize
# multiomics data. Nature Protocols. 2024, 19(11):3292-3320
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu. Gene Ontology Semantic Similarity Analysis Using
# GOSemSim. In: Kidder B. (eds) Stem Cell Transcriptional Networks.
# Methods in Molecular Biology. 2020, 2117:207-215. Humana, New York, NY.
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/16/motif_GCCTCA_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: BP"
# [1] "No significant enrichment results found."
# Error in file(file, ifelse(append, "a", "w")) :
#   cannot open the connection
# Calls: go_enrich ... write.csv -> eval.parent -> eval -> eval -> <Anonymous> -> file
# In addition: Warning message:
# In file(file, ifelse(append, "a", "w")) :
#   cannot open file 'data/negKG_louvain_communities/16/enrich_GCCTCA/go_enrichment_BP_results.csv': No such file or directory
# Execution halted
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan,
# X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal
# enrichment tool for interpreting omics data. The Innovation. 2021,
# 2(3):100141
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Guang-Rong Yan, Qing-Yu He. DOSE: an
# R/Bioconductor package for Disease Ontology Semantic and Enrichment
# analysis. Bioinformatics. 2015, 31(4):608-609
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/16/feature_700_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: BP"
# [1] "No significant enrichment results found."
# Error in file(file, ifelse(append, "a", "w")) :
#   cannot open the connection
# Calls: go_enrich ... write.csv -> eval.parent -> eval -> eval -> <Anonymous> -> file
# In addition: Warning message:
# In file(file, ifelse(append, "a", "w")) :
#   cannot open file 'data/negKG_louvain_communities/16/enrich_700/go_enrichment_BP_results.csv': No such file or directory
# Execution halted
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Guang-Rong Yan, Qing-Yu He. DOSE: an
# R/Bioconductor package for Disease Ontology Semantic and Enrichment
# analysis. Bioinformatics. 2015, 31(4):608-609
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/33/motif_CACTTT_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: BP"
# [1] "No significant enrichment results found."
# Error in file(file, ifelse(append, "a", "w")) :
#   cannot open the connection
# Calls: go_enrich ... write.csv -> eval.parent -> eval -> eval -> <Anonymous> -> file
# In addition: Warning message:
# In file(file, ifelse(append, "a", "w")) :
#   cannot open file 'data/negKG_louvain_communities/33/enrich_CACTTT/go_enrichment_BP_results.csv': No such file or directory
# Execution halted
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# S Xu, E Hu, Y Cai, Z Xie, X Luo, L Zhan, W Tang, Q Wang, B Liu, R Wang,
# W Xie, T Wu, L Xie, G Yu. Using clusterProfiler to characterize
# multiomics data. Nature Protocols. 2024, 19(11):3292-3320
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Guang-Rong Yan, Qing-Yu He. DOSE: an
# R/Bioconductor package for Disease Ontology Semantic and Enrichment
# analysis. Bioinformatics. 2015, 31(4):608-609
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/33/feature_8097_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: BP"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/33/enrich_8097"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan,
# X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal
# enrichment tool for interpreting omics data. The Innovation. 2021,
# 2(3):100141
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Guang-Rong Yan, Qing-Yu He. DOSE: an
# R/Bioconductor package for Disease Ontology Semantic and Enrichment
# analysis. Bioinformatics. 2015, 31(4):608-609
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/42/feature_3794_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: BP"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/42/enrich_3794"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# S Xu, E Hu, Y Cai, Z Xie, X Luo, L Zhan, W Tang, Q Wang, B Liu, R Wang,
# W Xie, T Wu, L Xie, G Yu. Using clusterProfiler to characterize
# multiomics data. Nature Protocols. 2024, 19(11):3292-3320
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/42/motif_AGCCTC_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: BP"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/42/enrich_AGCCTC"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Guang-Rong Yan, Qing-Yu He. DOSE: an
# R/Bioconductor package for Disease Ontology Semantic and Enrichment
# analysis. Bioinformatics. 2015, 31(4):608-609
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# ...
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/22/feature_10234_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: BP"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/22/enrich_10234"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/22/motif_GGTCTC_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: BP"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/22/enrich_GGTCTC"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan,
# X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal
# enrichment tool for interpreting omics data. The Innovation. 2021,
# 2(3):100141
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# S Xu, E Hu, Y Cai, Z Xie, X Luo, L Zhan, W Tang, Q Wang, B Liu, R Wang,
# W Xie, T Wu, L Xie, G Yu. Using clusterProfiler to characterize
# multiomics data. Nature Protocols. 2024, 19(11):3292-3320
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/24/feature_526_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: BP"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/24/enrich_526"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Qianwen Wang, Ming Li, Tianzhi Wu, Li Zhan, Lin Li, Meijun Chen, Wenqin
# Xie, Zijing Xie, Erqiang Hu, Shuangbin Xu, Guangchuang Yu. Exploring
# epigenomic datasets by ChIPseeker. Current Protocols. 2022, 2(10): e585
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/24/motif_GCCTCC_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: BP"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/24/enrich_GCCTCC"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.

# %%
# molecular function enrichment as well

neg_gene_sets = [f for f in os.listdir("data/neg_gene_sets") if f.endswith("_genes.txt")]
for gs in neg_gene_sets:
    os.system(f"Rscript enrich.R --gene_list data/neg_gene_sets/{gs} --outdir data/neg_gene_sets/enrich_{gs.split('_')[1]} --ont MF")

for c in os.listdir("data/negKG_louvain_communities"):
    neg_gene_sets = [f for f in os.listdir(f"data/negKG_louvain_communities/{c}") if f.endswith("_genes.txt")]
    for gs in neg_gene_sets:
        os.system(f"Rscript enrich.R --gene_list data/negKG_louvain_communities/{c}/{gs} --outdir data/negKG_louvain_communities/{c}/enrich_{gs.split('_')[1]} --ont MF")
# Out:
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Guang-Rong Yan, Qing-Yu He. DOSE: an
# R/Bioconductor package for Disease Ontology Semantic and Enrichment
# analysis. Bioinformatics. 2015, 31(4):608-609
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/neg_gene_sets/feature_8161_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: MF"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/neg_gene_sets/enrich_8161"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan,
# X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal
# enrichment tool for interpreting omics data. The Innovation. 2021,
# 2(3):100141
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Qianwen Wang, Ming Li, Tianzhi Wu, Li Zhan, Lin Li, Meijun Chen, Wenqin
# Xie, Zijing Xie, Erqiang Hu, Shuangbin Xu, Guangchuang Yu. Exploring
# epigenomic datasets by ChIPseeker. Current Protocols. 2022, 2(10): e585
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/neg_gene_sets/feature_3378_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: MF"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/neg_gene_sets/enrich_3378"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# S Xu, E Hu, Y Cai, Z Xie, X Luo, L Zhan, W Tang, Q Wang, B Liu, R Wang,
# W Xie, T Wu, L Xie, G Yu. Using clusterProfiler to characterize
# multiomics data. Nature Protocols. 2024, 19(11):3292-3320
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/neg_gene_sets/feature_7030_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: MF"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/neg_gene_sets/enrich_7030"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu. Gene Ontology Semantic Similarity Analysis Using
# GOSemSim. In: Kidder B. (eds) Stem Cell Transcriptional Networks.
# Methods in Molecular Biology. 2020, 2117:207-215. Humana, New York, NY.
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/neg_gene_sets/all_coding_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: MF"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/neg_gene_sets/enrich_coding"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Qing-Yu He. ReactomePA: an R/Bioconductor package for
# reactome pathway analysis and visualization. Molecular BioSystems.
# 2016, 12(2):477-479
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/1/motif_AGAAAA_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: MF"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/1/enrich_AGAAAA"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/1/feature_7030_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: MF"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/1/enrich_7030"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# S Xu, E Hu, Y Cai, Z Xie, X Luo, L Zhan, W Tang, Q Wang, B Liu, R Wang,
# W Xie, T Wu, L Xie, G Yu. Using clusterProfiler to characterize
# multiomics data. Nature Protocols. 2024, 19(11):3292-3320
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu. Gene Ontology Semantic Similarity Analysis Using
# GOSemSim. In: Kidder B. (eds) Stem Cell Transcriptional Networks.
# Methods in Molecular Biology. 2020, 2117:207-215. Humana, New York, NY.
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/16/motif_GCCTCA_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: MF"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/16/enrich_GCCTCA"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Qianwen Wang, Ming Li, Tianzhi Wu, Li Zhan, Lin Li, Meijun Chen, Wenqin
# Xie, Zijing Xie, Erqiang Hu, Shuangbin Xu, Guangchuang Yu. Exploring
# epigenomic datasets by ChIPseeker. Current Protocols. 2022, 2(10): e585
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/16/feature_700_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: MF"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/16/enrich_700"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu. Using meshes for MeSH term enrichment and semantic
# analyses. Bioinformatics. 2018, 34(21):3766-3767,
# doi:10.1093/bioinformatics/bty410
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/33/motif_CACTTT_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: MF"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/33/enrich_CACTTT"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Qing-Yu He. ReactomePA: an R/Bioconductor package for
# reactome pathway analysis and visualization. Molecular BioSystems.
# 2016, 12(2):477-479
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/33/feature_8097_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: MF"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/33/enrich_8097"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# S Xu, E Hu, Y Cai, Z Xie, X Luo, L Zhan, W Tang, Q Wang, B Liu, R Wang,
# W Xie, T Wu, L Xie, G Yu. Using clusterProfiler to characterize
# multiomics data. Nature Protocols. 2024, 19(11):3292-3320
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Qing-Yu He. ReactomePA: an R/Bioconductor package for
# reactome pathway analysis and visualization. Molecular BioSystems.
# 2016, 12(2):477-479
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/42/feature_3794_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: MF"
# [1] "No significant enrichment results found."
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu. Using meshes for MeSH term enrichment and semantic
# analyses. Bioinformatics. 2018, 34(21):3766-3767,
# doi:10.1093/bioinformatics/bty410
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/42/motif_AGCCTC_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: MF"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/42/enrich_AGCCTC"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# S Xu, E Hu, Y Cai, Z Xie, X Luo, L Zhan, W Tang, Q Wang, B Liu, R Wang,
# W Xie, T Wu, L Xie, G Yu. Using clusterProfiler to characterize
# multiomics data. Nature Protocols. 2024, 19(11):3292-3320
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# ...
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/36/feature_8204_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: MF"
# [1] "No significant enrichment results found."
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# S Xu, E Hu, Y Cai, Z Xie, X Luo, L Zhan, W Tang, Q Wang, B Liu, R Wang,
# W Xie, T Wu, L Xie, G Yu. Using clusterProfiler to characterize
# multiomics data. Nature Protocols. 2024, 19(11):3292-3320
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/22/feature_10234_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: MF"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/22/enrich_10234"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/22/motif_GGTCTC_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: MF"
# [1] "No significant enrichment results found."
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan,
# X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal
# enrichment tool for interpreting omics data. The Innovation. 2021,
# 2(3):100141
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/24/feature_526_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: MF"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/24/enrich_526"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan,
# X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal
# enrichment tool for interpreting omics data. The Innovation. 2021,
# 2(3):100141
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/24/motif_GCCTCC_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: MF"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/24/enrich_GCCTCC"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.

# %%
# cellular component enrichment as well

neg_gene_sets = [f for f in os.listdir("data/neg_gene_sets") if f.endswith("_genes.txt")]
for gs in neg_gene_sets:
    os.system(f"Rscript enrich.R --gene_list data/neg_gene_sets/{gs} --outdir data/neg_gene_sets/enrich_{gs.split('_')[1]} --ont CC")

for c in os.listdir("data/negKG_louvain_communities"):
    neg_gene_sets = [f for f in os.listdir(f"data/negKG_louvain_communities/{c}") if f.endswith("_genes.txt")]
    for gs in neg_gene_sets:
        os.system(f"Rscript enrich.R --gene_list data/negKG_louvain_communities/{c}/{gs} --outdir data/negKG_louvain_communities/{c}/enrich_{gs.split('_')[1]} --ont CC")
# Out:
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan,
# X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal
# enrichment tool for interpreting omics data. The Innovation. 2021,
# 2(3):100141
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Qing-Yu He. ReactomePA: an R/Bioconductor package for
# reactome pathway analysis and visualization. Molecular BioSystems.
# 2016, 12(2):477-479
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/neg_gene_sets/feature_8161_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: CC"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/neg_gene_sets/enrich_8161"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Fei Li, Yide Qin, Xiaochen Bo, Yibo Wu and Shengqi
# Wang. GOSemSim: an R package for measuring semantic similarity among GO
# terms and gene products. Bioinformatics. 2010, 26(7):976-978
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/neg_gene_sets/feature_3378_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: CC"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/neg_gene_sets/enrich_3378"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, and Qing-Yu He. ChIPseeker: an
# R/Bioconductor package for ChIP peak annotation, comparison and
# visualization. Bioinformatics. 2015, 31(14):2382-2383
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/neg_gene_sets/feature_7030_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: CC"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/neg_gene_sets/enrich_7030"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# S Xu, E Hu, Y Cai, Z Xie, X Luo, L Zhan, W Tang, Q Wang, B Liu, R Wang,
# W Xie, T Wu, L Xie, G Yu. Using clusterProfiler to characterize
# multiomics data. Nature Protocols. 2024, 19(11):3292-3320
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu. Using meshes for MeSH term enrichment and semantic
# analyses. Bioinformatics. 2018, 34(21):3766-3767,
# doi:10.1093/bioinformatics/bty410
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/neg_gene_sets/all_coding_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: CC"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/neg_gene_sets/enrich_coding"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# S Xu, E Hu, Y Cai, Z Xie, X Luo, L Zhan, W Tang, Q Wang, B Liu, R Wang,
# W Xie, T Wu, L Xie, G Yu. Using clusterProfiler to characterize
# multiomics data. Nature Protocols. 2024, 19(11):3292-3320
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/1/motif_AGAAAA_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: CC"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/1/enrich_AGAAAA"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Qianwen Wang, Ming Li, Tianzhi Wu, Li Zhan, Lin Li, Meijun Chen, Wenqin
# Xie, Zijing Xie, Erqiang Hu, Shuangbin Xu, Guangchuang Yu. Exploring
# epigenomic datasets by ChIPseeker. Current Protocols. 2022, 2(10): e585
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/1/feature_7030_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: CC"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/1/enrich_7030"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan,
# X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal
# enrichment tool for interpreting omics data. The Innovation. 2021,
# 2(3):100141
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/16/motif_GCCTCA_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: CC"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/16/enrich_GCCTCA"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan,
# X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal
# enrichment tool for interpreting omics data. The Innovation. 2021,
# 2(3):100141
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/16/feature_700_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: CC"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/16/enrich_700"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan,
# X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal
# enrichment tool for interpreting omics data. The Innovation. 2021,
# 2(3):100141
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/33/motif_CACTTT_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: CC"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/33/enrich_CACTTT"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# S Xu, E Hu, Y Cai, Z Xie, X Luo, L Zhan, W Tang, Q Wang, B Liu, R Wang,
# W Xie, T Wu, L Xie, G Yu. Using clusterProfiler to characterize
# multiomics data. Nature Protocols. 2024, 19(11):3292-3320
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/33/feature_8097_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: CC"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/33/enrich_8097"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# S Xu, E Hu, Y Cai, Z Xie, X Luo, L Zhan, W Tang, Q Wang, B Liu, R Wang,
# W Xie, T Wu, L Xie, G Yu. Using clusterProfiler to characterize
# multiomics data. Nature Protocols. 2024, 19(11):3292-3320
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/42/feature_3794_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: CC"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/42/enrich_3794"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan,
# X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal
# enrichment tool for interpreting omics data. The Innovation. 2021,
# 2(3):100141
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu. Gene Ontology Semantic Similarity Analysis Using
# GOSemSim. In: Kidder B. (eds) Stem Cell Transcriptional Networks.
# Methods in Molecular Biology. 2020, 2117:207-215. Humana, New York, NY.
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/42/motif_AGCCTC_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: CC"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/42/enrich_AGCCTC"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
# ...
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Qianwen Wang, Ming Li, Tianzhi Wu, Li Zhan, Lin Li, Meijun Chen, Wenqin
# Xie, Zijing Xie, Erqiang Hu, Shuangbin Xu, Guangchuang Yu. Exploring
# epigenomic datasets by ChIPseeker. Current Protocols. 2022, 2(10): e585
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/22/feature_10234_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: CC"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/22/enrich_10234"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# G Yu. Thirteen years of clusterProfiler. The Innovation. 2024,
# 5(6):100722
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu. Using meshes for MeSH term enrichment and semantic
# analyses. Bioinformatics. 2018, 34(21):3766-3767,
# doi:10.1093/bioinformatics/bty410
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/22/motif_GGTCTC_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: CC"
# [1] "No significant enrichment results found."
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu, Li-Gen Wang, Yanyan Han and Qing-Yu He.
# clusterProfiler: an R package for comparing biological themes among
# gene clusters. OMICS: A Journal of Integrative Biology. 2012,
# 16(5):284-287
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Guangchuang Yu. Using meshes for MeSH term enrichment and semantic
# analyses. Bioinformatics. 2018, 34(21):3766-3767,
# doi:10.1093/bioinformatics/bty410
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/24/feature_526_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: CC"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/24/enrich_526"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
#
# clusterProfiler v4.16.0 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan,
# X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal
# enrichment tool for interpreting omics data. The Innovation. 2021,
# 2(3):100141
#
# Attaching package: ‘clusterProfiler’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# enrichplot v1.28.4 Learn more at https://yulab-smu.top/contribution-knowledge-mining/
#
# Please cite:
#
# Qianwen Wang, Ming Li, Tianzhi Wu, Li Zhan, Lin Li, Meijun Chen, Wenqin
# Xie, Zijing Xie, Erqiang Hu, Shuangbin Xu, Guangchuang Yu. Exploring
# epigenomic datasets by ChIPseeker. Current Protocols. 2022, 2(10): e585
# Welcome to enrichR
# Checking connections ...
# Enrichr ... Connection is Live!
# FlyEnrichr ... Connection is Live!
# WormEnrichr ... Connection is Live!
# YeastEnrichr ... Connection is Live!
# FishEnrichr ... Connection is Live!
# OxEnrichr ... Connection is Live!
#
# Attaching package: ‘generics’
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Attaching package: ‘IRanges’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# Attaching package: ‘AnnotationDbi’
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, setequal, union
#
# The following object is masked from ‘package:generics’:
#
#     explain
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "Reading gene list from: data/negKG_louvain_communities/24/motif_GCCTCC_genes.txt"
# [1] "Performing GO enrichment analysis for ontology: CC"
# [1] "Generating plots..."
# [1] "Saving results to directory: data/negKG_louvain_communities/24/enrich_GCCTCC"
# Warning messages:
# 1: Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggtangle package.
#   Please report the issue to the authors.
# 2: In fortify(object, showCategory = showCategory, by = x, ...) :
#   Arguments in `...` must be used.
# ✖ Problematic argument:
# • by = x
# ℹ Did you misspell an argument name?
# 3: `aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the enrichplot package.
#   Please report the issue at
#   <https://github.com/GuangchuangYu/enrichplot/issues>.
