# %%
import tensorflow as tf
import keras
from keras import layers
import numpy as np

# %%
autoencoder = keras.models.load_model(
    './autoencoder_test.keras', 
    compile=True
    )
print(autoencoder.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 autoencoder = keras.models.load_model(
#       2     './autoencoder_test.keras',
# ----> 3     custom_objects={"SparseAutoEncoder": SparseAutoEncoder},
#       4     compile=True
#       5     )
#       6 print(autoencoder.summary())
#
# NameError: name 'SparseAutoEncoder' is not defined
