# %%
import tensorflow as tf
import keras
from keras import layers
import numpy as np
# Out:
# 2024-10-29 13:49:37.651999: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-29 13:49:37.660997: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-29 13:49:37.672025: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-29 13:49:37.675248: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-29 13:49:37.683280: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
autoencoder = keras.models.load_model(
    'models/autoencoder_test.keras', 
    compile=True
    )
print(autoencoder.summary())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 autoencoder = keras.models.load_model(
#       2     'models/autoencoder_test.keras',
#       3     compile=True
#       4     )
#       5 print(autoencoder.summary())
#
# File ~/anaconda3/envs/hsg/lib/python3.12/site-packages/keras/src/saving/saving_api.py:182, in load_model(filepath, custom_objects, compile, safe_mode)
#     179         is_keras_zip = True
#     181 if is_keras_zip or is_keras_dir:
# --> 182     return saving_lib.load_model(
#     183         filepath,
#     184         custom_objects=custom_objects,
#     185         compile=compile,
#     186         safe_mode=safe_mode,
#     187     )
#     188 if str(filepath).endswith((".h5", ".hdf5")):
#     189     return legacy_h5_format.load_model_from_hdf5(
#     190         filepath, custom_objects=custom_objects, compile=compile
#     191     )
#
# File ~/anaconda3/envs/hsg/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:237, in load_model(filepath, custom_objects, compile, safe_mode)
#     232     raise ValueError(
#     233         "Invalid filename: expected a `.keras` extension. "
#     234         f"Received: filepath={filepath}"
#     235     )
#     236 with open(filepath, "rb") as f:
# --> 237     return _load_model_from_fileobj(
#     238         f, custom_objects, compile, safe_mode
#     239     )
#
# File ~/anaconda3/envs/hsg/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:314, in _load_model_from_fileobj(fileobj, custom_objects, compile, safe_mode)
#     311 with zf.open(_CONFIG_FILENAME, "r") as f:
#     312     config_json = f.read()
# --> 314 model = _model_from_config(
#     315     config_json, custom_objects, compile, safe_mode
#     316 )
#     318 all_filenames = zf.namelist()
#     319 weights_file_path = None
#
# File ~/anaconda3/envs/hsg/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:303, in _model_from_config(config_json, custom_objects, compile, safe_mode)
#     301 # Construct the model from the configuration file in the archive.
#     302 with ObjectSharingScope():
# --> 303     model = deserialize_keras_object(
#     304         config_dict, custom_objects, safe_mode=safe_mode
#     305     )
#     306 return model
#
# File ~/anaconda3/envs/hsg/lib/python3.12/site-packages/keras/src/saving/serialization_lib.py:694, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     691     if obj is not None:
#     692         return obj
# --> 694 cls = _retrieve_class_or_fn(
#     695     class_name,
#     696     registered_name,
#     697     module,
#     698     obj_type="class",
#     699     full_config=config,
#     700     custom_objects=custom_objects,
#     701 )
#     703 if isinstance(cls, types.FunctionType):
#     704     return cls
#
# File ~/anaconda3/envs/hsg/lib/python3.12/site-packages/keras/src/saving/serialization_lib.py:812, in _retrieve_class_or_fn(name, registered_name, module, obj_type, full_config, custom_objects)
#     809     if obj is not None:
#     810         return obj
# --> 812 raise TypeError(
#     813     f"Could not locate {obj_type} '{name}'. "
#     814     "Make sure custom classes are decorated with "
#     815     "`@keras.saving.register_keras_serializable()`. "
#     816     f"Full object config: {full_config}"
#     817 )
#
# TypeError: Could not locate class 'SparseAutoEncoder'. Make sure custom classes are decorated with `@keras.saving.register_keras_serializable()`. Full object config: {'module': None, 'class_name': 'SparseAutoEncoder', 'config': {'name': 'sparse_auto_encoder', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'encoder': {'module': None, 'class_name': 'Encoder', 'config': {'name': 'encoder', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 139801332109184}, 'input_layer': {'module': 'keras.layers', 'class_name': 'InputLayer', 'config': {'batch_shape': [None, 2048], 'dtype': 'float32', 'sparse': False, 'name': 'input_layer'}, 'registered_name': None}, 'features': {'module': 'keras.layers', 'class_name': 'Dense', 'config': {'name': 'dense', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 139801332109184}, 'activity_regularizer': {'module': 'keras.regularizers', 'class_name': 'L1', 'config': {'l1': 0.009999999776482582}, 'registered_name': None}, 'units': 8192, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': {'module': 'keras.regularizers', 'class_name': 'L1', 'config': {'l1': 0.009999999776482582}, 'registered_name': None}, 'bias_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'registered_name': None, 'build_config': {'input_shape': [None, 2048]}}}, 'registered_name': 'Custom>Encoder', 'build_config': {'input_shape': [None, 2048]}}, 'decoder': {'module': None, 'class_name': 'Decoder', 'config': {'name': 'decoder', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 139801332109184}, 'input_layer': {'class_name': '__keras_tensor__', 'config': {'shape': [None, 8192], 'dtype': 'float32', 'keras_history': ['input_layer_1', 0, 0]}}, 'output_layer': {'module': 'keras.layers', 'class_name': 'Dense', 'config': {'name': 'dense_1', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 139801332109184}, 'units': 2048, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'registered_name': None, 'build_config': {'input_shape': [None, 8192]}}}, 'registered_name': 'Custom>Decoder', 'build_config': {'input_shape': [None, 8192]}}, 'n_features': 8192}, 'registered_name': 'Custom>SparseAutoEncoder', 'build_config': {'input_shape': [None, 2048]}, 'compile_config': {'optimizer': {'module': 'keras.optimizers', 'class_name': 'Adam', 'config': {'name': 'adam', 'learning_rate': 0.0010000000474974513, 'weight_decay': None, 'clipnorm': None, 'global_clipnorm': None, 'clipvalue': None, 'use_ema': False, 'ema_momentum': 0.99, 'ema_overwrite_frequency': None, 'loss_scale_factor': None, 'gradient_accumulation_steps': None, 'beta_1': 0.9, 'beta_2': 0.98, 'epsilon': 1e-09, 'amsgrad': False}, 'registered_name': None}, 'loss': {'module': 'keras.losses', 'class_name': 'MeanSquaredError', 'config': {'name': 'mean_squared_error', 'reduction': 'sum_over_batch_size'}, 'registered_name': None}, 'loss_weights': None, 'metrics': [{'module': 'keras.metrics', 'c ...

# %%
from autoencoder import SparseAutoEncoder
# Out:
# === Generating Test Data ===
# === Initializing Model ===
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730227785.083247   17486 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730227785.112135   17486 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730227785.112282   17486 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730227785.113565   17486 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730227785.113664   17486 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730227785.113731   17486 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730227785.170628   17486 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730227785.170759   17486 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730227785.170841   17486 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 13:49:45.170916: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6264 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "sparse_auto_encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder (Encoder)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder (Decoder)               │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# None
# === Training Model ===
# Epoch 1/100
# I0000 00:00:1730227785.946200   17595 service.cc:146] XLA service 0x7f25d800ac40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1730227785.946220   17595 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Laptop GPU, Compute Capability 8.9
# 2024-10-29 13:49:45.964179: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-29 13:49:46.032644: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
# 2024-10-29 13:49:46.738227: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_168', 20 bytes spill stores, 20 bytes spill loads
#
# 2024-10-29 13:49:46.779717: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_168', 204 bytes spill stores, 204 bytes spill loads
#
# 2024-10-29 13:49:46.993043: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_168', 392 bytes spill stores, 300 bytes spill loads
#
# 2024-10-29 13:49:47.054696: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_168', 88 bytes spill stores, 88 bytes spill loads
#
# 2024-10-29 13:49:47.530185: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_312', 308 bytes spill stores, 284 bytes spill loads
#  6/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.0000e+00 - cosine_similarity: 0.6064 - loss: 2488.3113 - mean_squared_error: 0.2994
# I0000 00:00:1730227788.588895   17595 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - auc: 0.0000e+00 - cosine_similarity: 0.6728 - loss: 2295.7327 - mean_squared_error: 0.3090
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8604 - loss: 1645.8979 - mean_squared_error: 0.3218
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8633 - loss: 1336.0372 - mean_squared_error: 0.3119
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8626 - loss: 1085.4395 - mean_squared_error: 0.3009
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8600 - loss: 881.8925 - mean_squared_error: 0.2802
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8597 - loss: 737.3800 - mean_squared_error: 0.2604
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8604 - loss: 610.1434 - mean_squared_error: 0.2481
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8612 - loss: 493.1053 - mean_squared_error: 0.2397
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8616 - loss: 390.6476 - mean_squared_error: 0.2269
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8617 - loss: 316.5018 - mean_squared_error: 0.2013
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8621 - loss: 284.7033 - mean_squared_error: 0.1851
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8620 - loss: 283.6212 - mean_squared_error: 0.1803
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8620 - loss: 308.1577 - mean_squared_error: 0.1755
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8619 - loss: 361.1320 - mean_squared_error: 0.1499
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8614 - loss: 392.2419 - mean_squared_error: 0.1315
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8620 - loss: 406.2070 - mean_squared_error: 0.1249
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8626 - loss: 402.5370 - mean_squared_error: 0.1265
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8630 - loss: 376.4378 - mean_squared_error: 0.1236
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8631 - loss: 347.6321 - mean_squared_error: 0.1100
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8638 - loss: 345.9615 - mean_squared_error: 0.1096
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8642 - loss: 356.6127 - mean_squared_error: 0.1143
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8647 - loss: 355.1680 - mean_squared_error: 0.1151
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8650 - loss: 333.5874 - mean_squared_error: 0.1132
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8649 - loss: 320.7128 - mean_squared_error: 0.1016
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8648 - loss: 330.4747 - mean_squared_error: 0.0976
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8649 - loss: 340.4182 - mean_squared_error: 0.1009
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8651 - loss: 338.1886 - mean_squared_error: 0.1010
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8652 - loss: 326.4679 - mean_squared_error: 0.0950
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8651 - loss: 327.2112 - mean_squared_error: 0.0933
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8652 - loss: 331.3491 - mean_squared_error: 0.1004
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 178ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8653 - loss: 332.7473 - mean_squared_error: 0.0958
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8654 - loss: 323.7796 - mean_squared_error: 0.0943
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8653 - loss: 323.6130 - mean_squared_error: 0.0998
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8654 - loss: 325.0128 - mean_squared_error: 0.1059
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8653 - loss: 330.7127 - mean_squared_error: 0.0949
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8655 - loss: 337.5800 - mean_squared_error: 0.0942
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8655 - loss: 335.1651 - mean_squared_error: 0.0879
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8655 - loss: 322.2362 - mean_squared_error: 0.0875
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8655 - loss: 319.4366 - mean_squared_error: 0.0889
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8655 - loss: 329.6271 - mean_squared_error: 0.0853
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 187ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8653 - loss: 340.3353 - mean_squared_error: 0.0887
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8654 - loss: 334.0526 - mean_squared_error: 0.0884
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8652 - loss: 319.5957 - mean_squared_error: 0.0899
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8648 - loss: 319.3825 - mean_squared_error: 0.0888
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8650 - loss: 333.0925 - mean_squared_error: 0.0874
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8651 - loss: 338.5247 - mean_squared_error: 0.0900
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8650 - loss: 323.8562 - mean_squared_error: 0.0908
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8652 - loss: 314.4578 - mean_squared_error: 0.0946
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8650 - loss: 320.3604 - mean_squared_error: 0.0904
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.0000e+00 - cosine_similarity: 0.8649 - loss: 336.4649 - mean_squared_error: 0.0927
# === Saving Model ===
# Model saved to: ./models/autoencoder_test.keras
# Model: "sparse_auto_encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder (Encoder)               │ ?                      │    16,785,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder (Decoder)               │ ?                      │    16,779,264 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,694,018 (384.12 MB)
#  Trainable params: 33,564,672 (128.04 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 67,129,346 (256.08 MB)
# None

# %%
autoencoder = SparseAutoEncoder(encoding_size=2048, expansion_factor=4)
autoencoder.compile(optimizer='adam', loss='mse')

# %%
autoencoder.get_config()
# Out:
# {'name': 'sparse_auto_encoder_1',
#  'trainable': True,
#  'dtype': {'module': 'keras',
#   'class_name': 'DTypePolicy',
#   'config': {'name': 'float32'},
#   'registered_name': None},
#  'encoder': <Encoder name=encoder_1, built=False>,
#  'decoder': <Decoder name=decoder_1, built=False>,
#  'n_features': 8192}
